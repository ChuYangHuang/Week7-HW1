# %%
import pandas as pd
Location = "datasets/HEA01.xls" 
df = pd.read_excel(Location)
df.columns = ['Areaname','STCOU','HEA010198F','HEA010198N1',]

# %%
df
# Out:
#              Areaname  STCOU  HEA010198F  HEA010198N1
# 0       UNITED STATES      0           1         7024
# 1             ALABAMA   1000           1         7022
# 2         Autauga, AL   1001           0            0
# 3         Baldwin, AL   1003           0            0
# 4         Barbour, AL   1005           0            0
# 5            Bibb, AL   1007           0            0
# 6          Blount, AL   1009           0            0
# 7         Bullock, AL   1011           0            0
# 8          Butler, AL   1013           0            0
# 9         Calhoun, AL   1015           0            0
# 10       Chambers, AL   1017           0            0
# 11       Cherokee, AL   1019           0            0
# 12        Chilton, AL   1021           0            0
# 13        Choctaw, AL   1023           0            0
# 14         Clarke, AL   1025           0            0
# 15           Clay, AL   1027           0            0
# ...
